# %% [markdown]
# #  Crop Recommendation

# %% [markdown]
# * N - ratio of Nitrogen content in soil
# * P - ratio of Phosphorous content in soil
# * K - ratio of Potassium content in soil
# * temperature - temperature in degree Celsius
# * humidity - relative humidity in %
# * ph - ph value of the soil
# * rainfall - rainfall in mm
#
# [NPK Values](https://www.gardeningknowhow.com/garden-how-to/soil-fertilizers/fertilizer-numbers-npk.htm)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %matplotlib inline
sns.set_style("whitegrid")
sns.set_palette("Accent")

# %%
df = pd.read_csv("crop_recommendation.csv")

# %%
df.head(10)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5  69  37  42    23.058049  83.370118  7.073454  251.055000  rice
# 6  69  55  38    22.708838  82.639414  5.700806  271.324860  rice
# 7  94  53  40    20.277744  82.894086  5.718627  241.974195  rice
# 8  89  54  38    24.515881  83.535216  6.685346  230.446236  rice
# 9  68  58  38    23.223974  83.033227  6.336254  221.209196  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.isnull().sum(axis=0)
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df["label"].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
plt.hist(df["K"])
plt.title("Pottasium Histogram")
plt.show()

# %%
plt.hist(df["N"])
plt.title("Nitrogen Histogram")
plt.show()

# %%
plt.hist(df["P"])
plt.title("Phosphorus Histogram")
plt.show()

# %%
plt.hist(df["temperature"])
plt.title("Temperature Histogram")
plt.show()

# %%
plt.hist(df["rainfall"])
plt.title("Rainfall Histogram")
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.title("Nitrogen Requirements of Various Crops")
sns.stripplot(data = df,x = "N" , y = "label")
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.stripplot(data = df,x = "P" , y = "label")
plt.title("Nitrogen Requirements of Various Crops")
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.stripplot(data = df,x = "K" , y = "label")
plt.title("Pottasium Requirements of Various Crops")
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.stripplot(data = df,x = "rainfall" , y = "label")
plt.title("Rainfall Requirements of Various Crops")
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.stripplot(data = df,x = "humidity" , y = "label")
plt.title("Humidity Requirements of Various Crops")
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.stripplot(data = df,x = "temperature" , y = "label")
plt.title("Temperature Requirements of Various Crops")
plt.show()

# %%
# Out:
# (array([841., 635., 424.,  88.,  12.,   0.,   0.,   0.,   0., 200.]),
#  array([  5.,  25.,  45.,  65.,  85., 105., 125., 145., 165., 185., 205.]),
#  <a list of 10 Patch objects>)
